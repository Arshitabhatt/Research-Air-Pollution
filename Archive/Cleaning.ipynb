# %%
import tabula as tab
df2 = tab.read_pdf("Air_NAMP_2016_data.pdf", pages='all')
# df3 = tab.read_pdf("Air NAMP 2017 data.pdf", pages='all')
# df4 = tab.read_pdf("Air NAMP 2018 data.pdf", pages='all')
df2
# Out:
# Got stderr: Jan 31, 2020 3:22:05 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFO: OpenType Layout tables used in font Arial,Bold are not implemented in PDFBox and will be ignored
# [       Unnamed: 0      Unnamed: 1                          Unnamed: 2  \
#  0           State            City                            Location
#  1             NaN             NaN                                 NaN
#  2             NaN       Anantapur                        Kamala Nagar
#  3             NaN             NaN              GNC Toll Gate Tirumala
#  4             NaN         Chitoor    Near M/s. Nutrine Confectionery,
#  5             NaN             NaN                                 NaN
#  6             NaN             NaN                      Palamaner Road
#  7             NaN           Eluru         At Ashram Diagnostic Centre
#  8             NaN          Guntur     Near Hindu College, Market Road
# ...

# %%
# tab.convert_into("Air_NAMP_2016_data.pdf", "Air_NAMP_2016_data.csv", output_format="csv", pages='all')
tab.convert_into("Air_NAMP_2016_data.pdf", "Air_NAMP_2016_data.csv", output_format="csv", pages=3)
print("help")
# Out:
# help
